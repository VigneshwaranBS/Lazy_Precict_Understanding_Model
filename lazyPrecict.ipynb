# %%
# !pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: pandas in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: joblib in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lazypredict) (1.2.0)
# Collecting xgboost
#   Downloading xgboost-1.7.4-py3-none-win_amd64.whl (89.1 MB)
#      -------------------------------------- 89.1/89.1 MB 433.4 kB/s eta 0:00:00
# Requirement already satisfied: click in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lazypredict) (8.0.3)
# Requirement already satisfied: tqdm in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lazypredict) (4.64.0)
# Requirement already satisfied: scikit-learn in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lazypredict) (1.0.2)
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages)
#      ---------------------------------------- 1.0/1.0 MB 495.2 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from click->lazypredict) (0.4.4)
# Requirement already satisfied: scipy in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lightgbm->lazypredict) (1.10.0)
# Requirement already satisfied: wheel in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lightgbm->lazypredict) (0.37.1)
# Requirement already satisfied: numpy in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from lightgbm->lazypredict) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->lazypredict) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from pandas->lazypredict) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\vicky\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: xgboost, lightgbm, lazypredict
# Successfully installed lazypredict-0.2.12 lightgbm-3.3.5 xgboost-1.7.4
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

data =load_breast_cancer()
X= data.data
y= data.target

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.30,random_state =123)

clf = LazyClassifier(verbose=0, ignore_warnings=True ,custom_metric=None)

models , predictons = clf.fit(X_train , X_test , y_train , y_test)

print(models)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 23.85it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.60               0.50     0.50      0.45
#
#                                Time Taken
# Model
# LogisticRegression                   0.03
# SGDClassifier                        0.01
# LinearSVC                            0.01
# Perceptron                           0.01
# SVC                                  0.01
# RandomForestClassifier               0.15
# ExtraTreesClassifier                 0.08
# RidgeClassifier                      0.04
# QuadraticDiscriminantAnalysis        0.02
# AdaBoostClassifier                   0.17
# KNeighborsClassifier                 0.03
# LinearDiscriminantAnalysis           0.04
# CalibratedClassifierCV               0.03
# LGBMClassifier                       0.13
# XGBClassifier                        0.24
# BernoulliNB                          0.01
# RidgeClassifierCV                    0.01
# PassiveAggressiveClassifier          0.01
# DecisionTreeClassifier               0.02
# LabelPropagation                     0.03
# LabelSpreading                       0.02
# NuSVC                                0.02
# NearestCentroid                      0.00
# BaggingClassifier                    0.06
# ExtraTreeClassifier                  0.01
# GaussianNB                           0.01
# DummyClassifier                      0.01

# %%
# CLEAR UNDERSTANDING ABOUT MODELS

models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LogisticRegression                 0.99               0.99     0.99      0.99
# SGDClassifier                      0.99               0.99     0.99      0.99
# LinearSVC                          0.99               0.99     0.99      0.99
# Perceptron                         0.99               0.99     0.99      0.99
# SVC                                0.98               0.98     0.98      0.98
# RandomForestClassifier             0.98               0.98     0.98      0.98
# ExtraTreesClassifier               0.98               0.98     0.98      0.98
# RidgeClassifier                    0.98               0.98     0.98      0.98
# QuadraticDiscriminantAnalysis      0.98               0.98     0.98      0.98
# AdaBoostClassifier                 0.98               0.98     0.98      0.98
# KNeighborsClassifier               0.98               0.97     0.97      0.98
# LinearDiscriminantAnalysis         0.98               0.97     0.97      0.98
# CalibratedClassifierCV             0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# XGBClassifier                      0.97               0.97     0.97      0.97
# BernoulliNB                        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.97               0.96     0.96      0.97
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# DecisionTreeClassifier             0.96               0.96     0.96      0.96
# LabelPropagation                   0.96               0.96     0.96      0.96
# LabelSpreading                     0.96               0.96     0.96      0.96
# NuSVC                              0.96               0.96     0.96      0.96
# NearestCentroid                    0.96               0.96     0.96      0.96
# BaggingClassifier                  0.95               0.95     0.95      0.95
# ExtraTreeClassifier                0.96               0.95     0.95      0.96
# GaussianNB                         0.96               0.95     0.95      0.96
# DummyClassifier                    0.60               0.50     0.50      0.45
#
#                                Time Taken
# Model
# LogisticRegression                   0.03
# SGDClassifier                        0.01
# LinearSVC                            0.01
# Perceptron                           0.01
# SVC                                  0.01
# RandomForestClassifier               0.15
# ExtraTreesClassifier                 0.08
# RidgeClassifier                      0.04
# QuadraticDiscriminantAnalysis        0.02
# AdaBoostClassifier                   0.17
# KNeighborsClassifier                 0.03
# LinearDiscriminantAnalysis           0.04
# CalibratedClassifierCV               0.03
# LGBMClassifier                       0.13
# XGBClassifier                        0.24
# BernoulliNB                          0.01
# RidgeClassifierCV                    0.01
# PassiveAggressiveClassifier          0.01
# DecisionTreeClassifier               0.02
# LabelPropagation                     0.03
# LabelSpreading                       0.02
# NuSVC                                0.02
# NearestCentroid                      0.00
# BaggingClassifier                    0.06
# ExtraTreeClassifier                  0.01
# GaussianNB                           0.01
# DummyClassifier                      0.01

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn import datasets
from sklearn.utils import shuffle
import numpy as np

boston = datasets.load_boston()
X, y = shuffle(boston.data, boston.target, random_state=13)


offset = int(X.shape[0] * 0.9)

X_train, y_train = X[:offset], y[:offset]
X_test, y_test = X[offset:], y[offset:]

reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
# 100%|██████████| 42/42 [00:06<00:00,  6.68it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.03
# BaggingRegressor                             0.83       0.88  2.63        0.03
# NuSVR                                        0.82       0.86  2.76        0.01
# RandomForestRegressor                        0.81       0.86  2.79        0.29
# XGBRegressor                                 0.81       0.86  2.79        0.10
# GradientBoostingRegressor                    0.81       0.86  2.84        0.08
# ExtraTreesRegressor                          0.79       0.84  2.98        0.14
# HistGradientBoostingRegressor                0.77       0.83  3.06        0.47
# AdaBoostRegressor                            0.77       0.83  3.06        0.10
# PoissonRegressor                             0.77       0.83  3.11        0.01
# LGBMRegressor                                0.77       0.83  3.11        0.05
# KNeighborsRegressor                          0.77       0.83  3.12        0.02
# DecisionTreeRegressor                        0.65       0.74  3.79        0.01
# MLPRegressor                                 0.65       0.74  3.80        0.46
# HuberRegressor                               0.64       0.74  3.84        0.03
# GammaRegressor                               0.64       0.73  3.88        0.01
# LinearSVR                                    0.62       0.72  3.96        0.01
# RidgeCV                                      0.62       0.72  3.97        0.01
# BayesianRidge                                0.62       0.72  3.97        0.01
# Ridge                                        0.62       0.72  3.97        0.01
# TransformedTargetRegressor                   0.62       0.72  3.97        0.01
# LinearRegression                             0.62       0.72  3.97        0.01
# ElasticNetCV                                 0.62       0.72  3.98        0.03
# LassoCV                                      0.62       0.72  3.98        0.04
# LassoLarsIC                                  0.62       0.72  3.98        0.03
# LassoLarsCV                                  0.62       0.72  3.98        0.02
# Lars                                         0.61       0.72  3.99        0.02
# LarsCV                                       0.61       0.71  4.02        0.03
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.01
# ElasticNet                                   0.58       0.69  4.16        0.01
# Lasso                                        0.54       0.66  4.35        0.01
# RANSACRegressor                              0.53       0.65  4.41        0.05
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.01
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.01
# GaussianProcessRegressor                     0.23       0.43  5.65        0.04
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.01
# ExtraTreeRegressor                           0.08       0.32  6.17        0.01
# QuantileRegressor                           -0.35      -0.00  7.49        4.05
# DummyRegressor                              -0.38      -0.02  7.56        0.01
# LassoLars                                   -0.38      -0.02  7.56        0.01
# KernelRidge                                -11.50      -8.25 22.74        0.03

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# SVR                                          0.83       0.88  2.62        0.03
# BaggingRegressor                             0.83       0.88  2.63        0.03
# NuSVR                                        0.82       0.86  2.76        0.01
# RandomForestRegressor                        0.81       0.86  2.79        0.29
# XGBRegressor                                 0.81       0.86  2.79        0.10
# GradientBoostingRegressor                    0.81       0.86  2.84        0.08
# ExtraTreesRegressor                          0.79       0.84  2.98        0.14
# HistGradientBoostingRegressor                0.77       0.83  3.06        0.47
# AdaBoostRegressor                            0.77       0.83  3.06        0.10
# PoissonRegressor                             0.77       0.83  3.11        0.01
# LGBMRegressor                                0.77       0.83  3.11        0.05
# KNeighborsRegressor                          0.77       0.83  3.12        0.02
# DecisionTreeRegressor                        0.65       0.74  3.79        0.01
# MLPRegressor                                 0.65       0.74  3.80        0.46
# HuberRegressor                               0.64       0.74  3.84        0.03
# GammaRegressor                               0.64       0.73  3.88        0.01
# LinearSVR                                    0.62       0.72  3.96        0.01
# RidgeCV                                      0.62       0.72  3.97        0.01
# BayesianRidge                                0.62       0.72  3.97        0.01
# Ridge                                        0.62       0.72  3.97        0.01
# TransformedTargetRegressor                   0.62       0.72  3.97        0.01
# LinearRegression                             0.62       0.72  3.97        0.01
# ElasticNetCV                                 0.62       0.72  3.98        0.03
# LassoCV                                      0.62       0.72  3.98        0.04
# LassoLarsIC                                  0.62       0.72  3.98        0.03
# LassoLarsCV                                  0.62       0.72  3.98        0.02
# Lars                                         0.61       0.72  3.99        0.02
# LarsCV                                       0.61       0.71  4.02        0.03
# SGDRegressor                                 0.60       0.70  4.07        0.01
# TweedieRegressor                             0.59       0.70  4.12        0.01
# ElasticNet                                   0.58       0.69  4.16        0.01
# Lasso                                        0.54       0.66  4.35        0.01
# RANSACRegressor                              0.53       0.65  4.41        0.05
# OrthogonalMatchingPursuitCV                  0.45       0.59  4.78        0.01
# PassiveAggressiveRegressor                   0.37       0.54  5.09        0.01
# GaussianProcessRegressor                     0.23       0.43  5.65        0.04
# OrthogonalMatchingPursuit                    0.16       0.38  5.89        0.01
# ExtraTreeRegressor                           0.08       0.32  6.17        0.01
# QuantileRegressor                           -0.35      -0.00  7.49        4.05
# DummyRegressor                              -0.38      -0.02  7.56        0.01
# LassoLars                                   -0.38      -0.02  7.56        0.01
# KernelRidge                                -11.50      -8.25 22.74        0.03

# %% [markdown]
# importing external dataset

# %%
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('Titanic.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of         sex   age  sibsp  parch  fare embarked   class    who  alone  survived
# 0      male 22.00      1      0  7.25        S   Third    man  False         0
# 1    female 38.00      1      0 71.28        C   First  woman  False         1
# 2    female 26.00      0      0  7.92        S   Third  woman   True         1
# 3    female 35.00      1      0 53.10        S   First  woman  False         1
# 4      male 35.00      0      0  8.05        S   Third    man   True         0
# ..      ...   ...    ...    ...   ...      ...     ...    ...    ...       ...
# 886    male 27.00      0      0 13.00        S  Second    man   True         0
# 887  female 19.00      0      0 30.00        S   First  woman   True         1
# 888  female   NaN      1      2 23.45        S   Third  woman  False         0
# 889    male 26.00      0      0 30.00        C   First    man   True         1
# 890    male 32.00      0      0  7.75        Q   Third    man   True         0
#
# [891 rows x 10 columns]>

# %%
X=df.drop('survived',axis=1)
y=df.iloc[:,0]

# %%
X.head()
# Out:
#       sex   age  sibsp  parch  fare embarked  class    who  alone
# 0    male 22.00      1      0  7.25        S  Third    man  False
# 1  female 38.00      1      0 71.28        C  First  woman  False
# 2  female 26.00      0      0  7.92        S  Third  woman   True
# 3  female 35.00      1      0 53.10        S  First  woman  False
# 4    male 35.00      0      0  8.05        S  Third    man   True

# %%
y
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.25,random_state =123)

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=False, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  21%|██        | 6/29 [00:00<00:00, 28.24it/s]
# ROC AUC couldn't be calculated for AdaBoostClassifier
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for BaggingClassifier
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for BernoulliNB
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for CalibratedClassifierCV
# could not convert string to float: 'female'
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
# ROC AUC couldn't be calculated for DecisionTreeClassifier
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for DummyClassifier
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
#  41%|████▏     | 12/29 [00:00<00:00, 24.77it/s]
# ROC AUC couldn't be calculated for ExtraTreeClassifier
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for ExtraTreesClassifier
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for GaussianNB
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for KNeighborsClassifier
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for LabelPropagation
# could not convert string to float: 'female'
#  55%|█████▌    | 16/29 [00:00<00:00, 28.33it/s]
# ROC AUC couldn't be calculated for LabelSpreading
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for LinearDiscriminantAnalysis
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for LinearSVC
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for LogisticRegression
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for NearestCentroid
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for NuSVC
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for PassiveAggressiveClassifier
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for Perceptron
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for QuadraticDiscriminantAnalysis
# could not convert string to float: 'female'
# 100%|██████████| 29/29 [00:00<00:00, 31.43it/s]
# ROC AUC couldn't be calculated for RandomForestClassifier
# could not convert string to float: 'female'
# ROC AUC couldn't be calculated for RidgeClassifier
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for RidgeClassifierCV
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for SGDClassifier
# Unable to convert array of bytes/strings into decimal numbers with dtype='numeric'
# ROC AUC couldn't be calculated for SVC
# could not convert string to float: 'female'
# StackingClassifier model failed to execute
# StackingClassifier.__init__() missing 1 required positional argument: 'estimators'
# XGBClassifier model failed to execute
# Invalid classes inferred from unique values of `y`.  Expected: [0 1], got ['female' 'male']
# ROC AUC couldn't be calculated for LGBMClassifier
# could not convert string to float: 'female'

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# AdaBoostClassifier                 1.00               1.00    None      1.00
# BaggingClassifier                  1.00               1.00    None      1.00
# SVC                                1.00               1.00    None      1.00
# SGDClassifier                      1.00               1.00    None      1.00
# RidgeClassifierCV                  1.00               1.00    None      1.00
# RidgeClassifier                    1.00               1.00    None      1.00
# RandomForestClassifier             1.00               1.00    None      1.00
# Perceptron                         1.00               1.00    None      1.00
# PassiveAggressiveClassifier        1.00               1.00    None      1.00
# LogisticRegression                 1.00               1.00    None      1.00
# LinearSVC                          1.00               1.00    None      1.00
# GaussianNB                         1.00               1.00    None      1.00
# ExtraTreesClassifier               1.00               1.00    None      1.00
# ExtraTreeClassifier                1.00               1.00    None      1.00
# DecisionTreeClassifier             1.00               1.00    None      1.00
# CalibratedClassifierCV             1.00               1.00    None      1.00
# BernoulliNB                        1.00               1.00    None      1.00
# LGBMClassifier                     1.00               1.00    None      1.00
# LabelSpreading                     1.00               1.00    None      1.00
# LabelPropagation                   1.00               1.00    None      1.00
# KNeighborsClassifier               1.00               1.00    None      1.00
# NuSVC                              1.00               1.00    None      1.00
# LinearDiscriminantAnalysis         0.96               0.96    None      0.96
# NearestCentroid                    0.95               0.96    None      0.95
# QuadraticDiscriminantAnalysis      0.34               0.50    None      0.17
# DummyClassifier                    0.66               0.50    None      0.52
#
#                                Time Taken
# Model
# AdaBoostClassifier                   0.04
# BaggingClassifier                    0.04
# SVC                                  0.02
# SGDClassifier                        0.02
# RidgeClassifierCV                    0.03
# RidgeClassifier                      0.02
# RandomForestClassifier               0.11
# Perceptron                           0.01
# PassiveAggressiveClassifier          0.02
# LogisticRegression                   0.03
# LinearSVC                            0.02
# GaussianNB                           0.03
# ExtraTreesClassifier                 0.11
# ExtraTreeClassifier                  0.02
# DecisionTreeClassifier               0.02
# CalibratedClassifierCV               0.07
# BernoulliNB                          0.03
# LGBMClassifier                       0.03
# LabelSpreading                       0.04
# LabelPropagation                     0.04
# KNeighborsClassifier                 0.04
# NuSVC                                0.03
# LinearDiscriminantAnalysis           0.02
# NearestCentroid                      0.01
# QuadraticDiscriminantAnalysis        0.02
# DummyClassifier                      0.03
